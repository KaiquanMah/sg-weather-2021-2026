# %%
import pandas as pd

# Load the parquet file
file_path = '/content/raw_air-temperature_2020-12-01.parquet'
df = pd.read_parquet(file_path)

# Display the DataFrame
display(df.head())
# Out:
#                    timestamp station_id  value        date         endpoint  \
# 0  2020-12-01T23:59:00+08:00       S109   27.6  2020-12-01  air-temperature
# 1  2020-12-01T23:59:00+08:00       S117   29.1  2020-12-01  air-temperature
# 2  2020-12-01T23:59:00+08:00       S107   27.6  2020-12-01  air-temperature
# 3  2020-12-01T23:59:00+08:00        S43   28.0  2020-12-01  air-temperature
# 4  2020-12-01T23:59:00+08:00       S108   28.0  2020-12-01  air-temperature
#
#                    ingest_timestamp
# 0  2026-03-07T17:41:02.596343+08:00
# 1  2026-03-07T17:41:02.596381+08:00
# 2  2026-03-07T17:41:02.596395+08:00
# 3  2026-03-07T17:41:02.596406+08:00
# 4  2026-03-07T17:41:02.596416+08:00
